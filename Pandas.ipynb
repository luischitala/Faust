# %%
import pandas as pd
import numpy as np

# %%
el_universal = pd.read_csv('eluniversal_2020_06_28_articles.csv', engine='python')

# %%
el_universal
# Out:
#                     article_author article_date  article_location  \
# 0                               AP   28/06/2020               NaN
# 1                              NaN          NaN               NaN
# 2                              NaN          NaN               NaN
# 3                              NaN          NaN               NaN
# 4                      Alma GÃ³mez   28/06/2020               NaN
# ..                             ...          ...               ...
# 125                Araceli GarcÃ­a   28/06/2020               NaN
# 126                     RedacciÃ³n   28/04/2020               NaN
# 127  Carlos Arrieta / Corresponsal   28/06/2020               NaN
# 128                            NaN          NaN               NaN
# 129                            NaN          NaN               NaN
#
#                                                   body  \
# 0    Los Rolling Stones amenazaron el domingo al pr...
# 1    Como parte de las medidas de apoyo a las famil...
# 2    \r\nLa actriz Emilia Clarke fue captada por lo...
# 3    \r\nLos Centros para el Control y la PrevenciÃ...
# 4    \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ..                                                 ...
# 125  Durante esta Ã©poca de pandemia el influencer ...
# 126  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 127  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 128  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 129  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
#                                                  title  \
# 0    Los Rolling Stones amenazan con demandar a Don...
# 1    CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 2                                                  NaN
# 3                                                  NaN
# 4    ContinÃºan bajas las ventas en el Centro de Qu...
# ..                                                 ...
# 125  Juanma Salazar siente que ha crecido la compet...
# 126  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 127  No se presenta perito a juicio de mamÃ¡ de "El...
# 128                                                NaN
# 129  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
#                                                    url
# 0    http://www.eluniversal.com.mx/espectaculos/mus...
# 1    http://www.unionpuebla.mx/articulo/2020/05/26/...
# 2    https://www.viveusa.mx/showbiz/emilia-clarke-c...
# 3    https://www.viveusa.mx/bienestar/los-cdc-agreg...
# 4    https://www.eluniversalqueretaro.mx/portada/co...
# ..                                                 ...
# 125  http://www.eluniversal.com.mx/espectaculos/jua...
# 126  https://oaxaca.eluniversal.com.mx/estatal/28-0...
# 127  http://www.eluniversal.com.mx/estados/no-se-pr...
# 128  https://de10.com.mx/cultura-digital/demi-rose-...
# 129  http://www.unioncdmx.mx/articulo/2020/06/03/ed...
#
# [130 rows x 6 columns]

# %%
# dictionary like 

el_universal['title']
# Out:
# 0      Los Rolling Stones amenazan con demandar a Don...
# 1      CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 2                                                    NaN
# 3                                                    NaN
# 4      ContinÃºan bajas las ventas en el Centro de Qu...
#                              ...
# 125    Juanma Salazar siente que ha crecido la compet...
# 126    Vinculan a sujeto que presuntamente atacÃ³ sex...
# 127    No se presenta perito a juicio de mamÃ¡ de "El...
# 128                                                  NaN
# 129    Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
# Name: title, Length: 130, dtype: object

# %%
el_universal[['title','body']]
# Out:
#                                                  title  \
# 0    Los Rolling Stones amenazan con demandar a Don...
# 1    CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 2                                                  NaN
# 3                                                  NaN
# 4    ContinÃºan bajas las ventas en el Centro de Qu...
# ..                                                 ...
# 125  Juanma Salazar siente que ha crecido la compet...
# 126  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 127  No se presenta perito a juicio de mamÃ¡ de "El...
# 128                                                NaN
# 129  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
#                                                   body
# 0    Los Rolling Stones amenazaron el domingo al pr...
# 1    Como parte de las medidas de apoyo a las famil...
# 2    \r\nLa actriz Emilia Clarke fue captada por lo...
# 3    \r\nLos Centros para el Control y la PrevenciÃ...
# 4    \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ..                                                 ...
# 125  Durante esta Ã©poca de pandemia el influencer ...
# 126  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 127  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 128  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 129  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
# [130 rows x 2 columns]

# %%
#numpy like

el_universal.iloc[10:15]
# Out:
#             article_author article_date  article_location  \
# 10                     NaN   28/06/2020               NaN
# 11  Periodistas MetrÃ³poli   28/06/2020               NaN
# 12                     NaN   25/06/2020               NaN
# 13              RedacciÃ³n   28/06/2020               NaN
# 14                     NaN   28/06/2020               NaN
#
#                                                  body  \
# 10  \r\nHay veces que la expresiÃ³n mÃ¡s amorosa y...
# 11  \r\nLe platicamos que ayer los 16 alcaldes de ...
# 12              Texto: Carlos Villasana y Ruth GÃ³mez
# 13  \r\nJalisco tiene 6 mil 190 casos confirmados ...
# 14                              \r\nMadrid, EspaÃ±a.-
#
#                                                 title  \
# 10                         Â¿QuÃ© mÃºsica transmites?
# 11  El alcance de los ediles en materia de segurid...
# 12           Los primeros departamentos de la capital
# 13  Casos confirmados de Covid-19 en Jalisco al 27...
# 14  Crisis postcovid. Transportistas buscan ayuda ...
#
#                                                   url
# 10  https://www.eluniversal.com.mx/opinion/gaby-va...
# 11  http://www.eluniversal.com.mx/metropoli/el-alc...
# 12  https://www.eluniversal.com.mx/opinion/mochila...
# 13  http://www.eluniversal.com.mx/estados/coronavi...
# 14  https://www.eluniversalqueretaro.mx/portada/tr...

# %%
el_universal.iloc[66]['title']
# Out:
# 'Delegado de SLP declarÃ³ ganar 80 veces sueldo de AMLO'

# %%
el_universal.loc[:,'body':'title']
# Out:
#                                                   body  \
# 0    Los Rolling Stones amenazaron el domingo al pr...
# 1    Como parte de las medidas de apoyo a las famil...
# 2    \r\nLa actriz Emilia Clarke fue captada por lo...
# 3    \r\nLos Centros para el Control y la PrevenciÃ...
# 4    \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ..                                                 ...
# 125  Durante esta Ã©poca de pandemia el influencer ...
# 126  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 127  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 128  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 129  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
#                                                  title
# 0    Los Rolling Stones amenazan con demandar a Don...
# 1    CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 2                                                  NaN
# 3                                                  NaN
# 4    ContinÃºan bajas las ventas en el Centro de Qu...
# ..                                                 ...
# 125  Juanma Salazar siente que ha crecido la compet...
# 126  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 127  No se presenta perito a juicio de mamÃ¡ de "El...
# 128                                                NaN
# 129  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
# [130 rows x 2 columns]

# %%
# añadir el newsppaer_uid al dataframe

el_universal['newspaper_uid'] = 'eltiempo'

# %%
from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                     article_author article_date  article_location  \
# 0                               AP   28/06/2020               NaN
# 1                              NaN          NaN               NaN
# 2                              NaN          NaN               NaN
# 3                              NaN          NaN               NaN
# 4                      Alma GÃ³mez   28/06/2020               NaN
# ..                             ...          ...               ...
# 125                Araceli GarcÃ­a   28/06/2020               NaN
# 126                     RedacciÃ³n   28/04/2020               NaN
# 127  Carlos Arrieta / Corresponsal   28/06/2020               NaN
# 128                            NaN          NaN               NaN
# 129                            NaN          NaN               NaN
#
#                                                   body  \
# 0    Los Rolling Stones amenazaron el domingo al pr...
# 1    Como parte de las medidas de apoyo a las famil...
# 2    \r\nLa actriz Emilia Clarke fue captada por lo...
# 3    \r\nLos Centros para el Control y la PrevenciÃ...
# 4    \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ..                                                 ...
# 125  Durante esta Ã©poca de pandemia el influencer ...
# 126  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 127  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 128  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 129  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
#                                                  title  \
# 0    Los Rolling Stones amenazan con demandar a Don...
# 1    CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 2                                                  NaN
# 3                                                  NaN
# 4    ContinÃºan bajas las ventas en el Centro de Qu...
# ..                                                 ...
# 125  Juanma Salazar siente que ha crecido la compet...
# 126  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 127  No se presenta perito a juicio de mamÃ¡ de "El...
# 128                                                NaN
# 129  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
#                                                    url newspaper_uid  \
# 0    http://www.eluniversal.com.mx/espectaculos/mus...      eltiempo
# 1    http://www.unionpuebla.mx/articulo/2020/05/26/...      eltiempo
# 2    https://www.viveusa.mx/showbiz/emilia-clarke-c...      eltiempo
# 3    https://www.viveusa.mx/bienestar/los-cdc-agreg...      eltiempo
# 4    https://www.eluniversalqueretaro.mx/portada/co...      eltiempo
# ..                                                 ...           ...
# 125  http://www.eluniversal.com.mx/espectaculos/jua...      eltiempo
# 126  https://oaxaca.eluniversal.com.mx/estatal/28-0...      eltiempo
# 127  http://www.eluniversal.com.mx/estados/no-se-pr...      eltiempo
# 128  https://de10.com.mx/cultura-digital/demi-rose-...      eltiempo
# 129  http://www.unioncdmx.mx/articulo/2020/06/03/ed...      eltiempo
#
#                             host
# 0         www.eluniversal.com.mx
# 1             www.unionpuebla.mx
# 2                 www.viveusa.mx
# 3                 www.viveusa.mx
# 4    www.eluniversalqueretaro.mx
# ..                           ...
# 125       www.eluniversal.com.mx
# 126    oaxaca.eluniversal.com.mx
# 127       www.eluniversal.com.mx
# 128                  de10.com.mx
# 129             www.unioncdmx.mx
#
# [130 rows x 8 columns]

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         76
# www.viveusa.mx                 15
# sanluis.eluniversal.com.mx      5
# de10.com.mx                     5
# oaxaca.eluniversal.com.mx       5
# www.elgrafico.mx                5
# www.eluniversalqueretaro.mx     5
# www.unionyucatan.mx             4
# www.unionjalisco.mx             3
# www.unionpuebla.mx              2
# www.unioncdmx.mx                2
# www.unionguanajuato.mx          2
# www.unionedomex.mx              1
# Name: host, dtype: int64

# %% [markdown]
# # Missing Data

# %%
# Rellenar datos faltantes 

missing_titles_mask = el_universal['title'].isna()


missing_titles = (el_universal[missing_titles_mask]['url']
    .str.extract(r'(?P<missing_titles>[^/]+)$')
    .applymap(lambda title: title.split('-'))
    .applymap(lambda title_word_list: ' '.join(title_word_list)))

missing_titles
# Out:
#                                         missing_titles
# 2    emilia clarke conquista londres con leggings n...
# 3    los cdc agregan tres posibles sintomas de covi...
# 6    kylie jenner remarca su figura con pantalones ...
# 7    alertan por desinfectante de manos potencialme...
# 15   muere lady zote por covid 19 y diabetes se hiz...
# 20   cuales son las visas que trump congelo hasta 2021
# 24   la bebeshita sorprende con candente baile para...
# 26   sicarios ejecutan lider de comerciantes en el ...
# 27   la chiquis rivera festejo sus 35 anos quitando...
# 36   requisitos para el programa de trabajadores ag...
# 39   41 mil dolares para barista que nego servicio ...
# 41   la intensa rutina diaria de mark zuckerberg cr...
# 47   kendall jenner apuesta por lenceria para sesio...
# 53   eiza gonzalez se disculpa por blackface que mo...
# 59   el lujoso estilo de vida de eve la hija de ste...
# 70   jennifer lopez enciende el verano con traje de...
# 72   fallece hijo de juan carlos romero hicks coord...
# 90   salma hayek baila en bikini con su throwback m...
# 94   las hermanas wachowski y su dura transicion se...
# 99   coronavirus se puede viajar de mexico estados ...
# 108  elecciones 2020 quien puede votar en estados u...
# 115  10 errores garrafales que hemos cometido en la...
# 116  tratamientos inhumanos con los que curaban la ...
# 121        las 10 razas de perro mas grandes del mundo
# 128  demi rose la modelo que causa sensacion en las...

# %%
el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']

# %% [markdown]
# # Additional Cleanup

# %%
# 4. Añadir uid a las filas 

import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
)

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)
el_universal
# Out:
#                                                  article_author article_date  \
# uid
# a208fa9260371d726a41b10b41ff83bc                             AP   28/06/2020
# 602fe4651de5d33fa8b8a896179d2805                            NaN          NaN
# 785bd930682054e238b68a7bd8dfffbe                            NaN          NaN
# 8575c3932ba6cb712425f5b20c6ee6bc                            NaN          NaN
# e719ff2dcc196a496b8dd11b3c2062e4                    Alma GÃ³mez   28/06/2020
# ...                                                         ...          ...
# aa97a9136824bfced0e892686b81b6ee                Araceli GarcÃ­a   28/06/2020
# 1e6f4ed28824897fe2c39e7e15643dfc                     RedacciÃ³n   28/04/2020
# 67e5438eba106c3959093ff2f5b0f5dd  Carlos Arrieta / Corresponsal   28/06/2020
# 17b73d5477c6ed9c35ff467370cc4325                            NaN          NaN
# 5d46615728015b7fd8282292d4d6c7ca                            NaN          NaN
#
#                                   article_location  \
# uid
# a208fa9260371d726a41b10b41ff83bc               NaN
# 602fe4651de5d33fa8b8a896179d2805               NaN
# 785bd930682054e238b68a7bd8dfffbe               NaN
# 8575c3932ba6cb712425f5b20c6ee6bc               NaN
# e719ff2dcc196a496b8dd11b3c2062e4               NaN
# ...                                            ...
# aa97a9136824bfced0e892686b81b6ee               NaN
# 1e6f4ed28824897fe2c39e7e15643dfc               NaN
# 67e5438eba106c3959093ff2f5b0f5dd               NaN
# 17b73d5477c6ed9c35ff467370cc4325               NaN
# 5d46615728015b7fd8282292d4d6c7ca               NaN
#
#                                                                                body  \
# uid
# a208fa9260371d726a41b10b41ff83bc  Los Rolling Stones amenazaron el domingo al pr...
# 602fe4651de5d33fa8b8a896179d2805  Como parte de las medidas de apoyo a las famil...
# 785bd930682054e238b68a7bd8dfffbe  \r\nLa actriz Emilia Clarke fue captada por lo...
# 8575c3932ba6cb712425f5b20c6ee6bc  \r\nLos Centros para el Control y la PrevenciÃ...
# e719ff2dcc196a496b8dd11b3c2062e4  \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  Durante esta Ã©poca de pandemia el influencer ...
# 1e6f4ed28824897fe2c39e7e15643dfc  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 67e5438eba106c3959093ff2f5b0f5dd  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 17b73d5477c6ed9c35ff467370cc4325  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 5d46615728015b7fd8282292d4d6c7ca  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
#                                                                               title  \
# uid
# a208fa9260371d726a41b10b41ff83bc  Los Rolling Stones amenazan con demandar a Don...
# 602fe4651de5d33fa8b8a896179d2805  CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 785bd930682054e238b68a7bd8dfffbe  emilia clarke conquista londres con leggings n...
# 8575c3932ba6cb712425f5b20c6ee6bc  los cdc agregan tres posibles sintomas de covi...
# e719ff2dcc196a496b8dd11b3c2062e4  ContinÃºan bajas las ventas en el Centro de Qu...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  Juanma Salazar siente que ha crecido la compet...
# 1e6f4ed28824897fe2c39e7e15643dfc  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 67e5438eba106c3959093ff2f5b0f5dd  No se presenta perito a juicio de mamÃ¡ de "El...
# 17b73d5477c6ed9c35ff467370cc4325  demi rose la modelo que causa sensacion en las...
# 5d46615728015b7fd8282292d4d6c7ca  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
#                                                                                 url  \
# uid
# a208fa9260371d726a41b10b41ff83bc  http://www.eluniversal.com.mx/espectaculos/mus...
# 602fe4651de5d33fa8b8a896179d2805  http://www.unionpuebla.mx/articulo/2020/05/26/...
# 785bd930682054e238b68a7bd8dfffbe  https://www.viveusa.mx/showbiz/emilia-clarke-c...
# 8575c3932ba6cb712425f5b20c6ee6bc  https://www.viveusa.mx/bienestar/los-cdc-agreg...
# e719ff2dcc196a496b8dd11b3c2062e4  https://www.eluniversalqueretaro.mx/portada/co...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  http://www.eluniversal.com.mx/espectaculos/jua...
# 1e6f4ed28824897fe2c39e7e15643dfc  https://oaxaca.eluniversal.com.mx/estatal/28-0...
# 67e5438eba106c3959093ff2f5b0f5dd  http://www.eluniversal.com.mx/estados/no-se-pr...
# 17b73d5477c6ed9c35ff467370cc4325  https://de10.com.mx/cultura-digital/demi-rose-...
# 5d46615728015b7fd8282292d4d6c7ca  http://www.unioncdmx.mx/articulo/2020/06/03/ed...
#
#                                  newspaper_uid                         host
# uid
# a208fa9260371d726a41b10b41ff83bc      eltiempo       www.eluniversal.com.mx
# 602fe4651de5d33fa8b8a896179d2805      eltiempo           www.unionpuebla.mx
# 785bd930682054e238b68a7bd8dfffbe      eltiempo               www.viveusa.mx
# 8575c3932ba6cb712425f5b20c6ee6bc      eltiempo               www.viveusa.mx
# e719ff2dcc196a496b8dd11b3c2062e4      eltiempo  www.eluniversalqueretaro.mx
# ...                                        ...                          ...
# aa97a9136824bfced0e892686b81b6ee      eltiempo       www.eluniversal.com.mx
# 1e6f4ed28824897fe2c39e7e15643dfc      eltiempo    oaxaca.eluniversal.com.mx
# 67e5438eba106c3959093ff2f5b0f5dd      eltiempo       www.eluniversal.com.mx
# 17b73d5477c6ed9c35ff467370cc4325      eltiempo                  de10.com.mx
# 5d46615728015b7fd8282292d4d6c7ca      eltiempo             www.unioncdmx.mx
#
# [130 rows x 8 columns]

# %%
stripped_body = (el_universal
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ' '),letters)))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\r', ''),letters)))
                     .apply(lambda letters: ''.join(letters))

)
stripped_body
# Out:
# uid
# a208fa9260371d726a41b10b41ff83bc    Los Rolling Stones amenazaron el domingo al pr...
# 602fe4651de5d33fa8b8a896179d2805    Como parte de las medidas de apoyo a las famil...
# 785bd930682054e238b68a7bd8dfffbe     La actriz Emilia Clarke fue captada por los p...
# 8575c3932ba6cb712425f5b20c6ee6bc     Los Centros para el Control y la PrevenciÃ³n ...
# e719ff2dcc196a496b8dd11b3c2062e4     Durante la llamada â€œnueva normalidadâ€� las...
#                                                           ...
# aa97a9136824bfced0e892686b81b6ee    Durante esta Ã©poca de pandemia el influencer ...
# 1e6f4ed28824897fe2c39e7e15643dfc     La FiscalÃ­a General del Estado de Oaxaca (FG...
# 67e5438eba106c3959093ff2f5b0f5dd     Guanajuato. â€” Este sÃ¡bado se realizÃ³ la s...
# 17b73d5477c6ed9c35ff467370cc4325    Demi Rose Mawby es una modelo britÃ¡nica que c...
# 5d46615728015b7fd8282292d4d6c7ca    La ComisiÃ³n Metropolitana de Instituciones PÃ...
# Length: 130, dtype: object

# %%
el_universal.head()
el_universal = el_universal.drop(['article_date', 'article_author', 'article_location'], axis=1)

# %%
el_universal
# Out:
#                                                                                body  \
# uid
# a208fa9260371d726a41b10b41ff83bc  Los Rolling Stones amenazaron el domingo al pr...
# 602fe4651de5d33fa8b8a896179d2805  Como parte de las medidas de apoyo a las famil...
# 785bd930682054e238b68a7bd8dfffbe  \r\nLa actriz Emilia Clarke fue captada por lo...
# 8575c3932ba6cb712425f5b20c6ee6bc  \r\nLos Centros para el Control y la PrevenciÃ...
# e719ff2dcc196a496b8dd11b3c2062e4  \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  Durante esta Ã©poca de pandemia el influencer ...
# 1e6f4ed28824897fe2c39e7e15643dfc  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 67e5438eba106c3959093ff2f5b0f5dd  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 17b73d5477c6ed9c35ff467370cc4325  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 5d46615728015b7fd8282292d4d6c7ca  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
#                                                                               title  \
# uid
# a208fa9260371d726a41b10b41ff83bc  Los Rolling Stones amenazan con demandar a Don...
# 602fe4651de5d33fa8b8a896179d2805  CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 785bd930682054e238b68a7bd8dfffbe  emilia clarke conquista londres con leggings n...
# 8575c3932ba6cb712425f5b20c6ee6bc  los cdc agregan tres posibles sintomas de covi...
# e719ff2dcc196a496b8dd11b3c2062e4  ContinÃºan bajas las ventas en el Centro de Qu...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  Juanma Salazar siente que ha crecido la compet...
# 1e6f4ed28824897fe2c39e7e15643dfc  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 67e5438eba106c3959093ff2f5b0f5dd  No se presenta perito a juicio de mamÃ¡ de "El...
# 17b73d5477c6ed9c35ff467370cc4325  demi rose la modelo que causa sensacion en las...
# 5d46615728015b7fd8282292d4d6c7ca  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
#                                                                                 url  \
# uid
# a208fa9260371d726a41b10b41ff83bc  http://www.eluniversal.com.mx/espectaculos/mus...
# 602fe4651de5d33fa8b8a896179d2805  http://www.unionpuebla.mx/articulo/2020/05/26/...
# 785bd930682054e238b68a7bd8dfffbe  https://www.viveusa.mx/showbiz/emilia-clarke-c...
# 8575c3932ba6cb712425f5b20c6ee6bc  https://www.viveusa.mx/bienestar/los-cdc-agreg...
# e719ff2dcc196a496b8dd11b3c2062e4  https://www.eluniversalqueretaro.mx/portada/co...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  http://www.eluniversal.com.mx/espectaculos/jua...
# 1e6f4ed28824897fe2c39e7e15643dfc  https://oaxaca.eluniversal.com.mx/estatal/28-0...
# 67e5438eba106c3959093ff2f5b0f5dd  http://www.eluniversal.com.mx/estados/no-se-pr...
# 17b73d5477c6ed9c35ff467370cc4325  https://de10.com.mx/cultura-digital/demi-rose-...
# 5d46615728015b7fd8282292d4d6c7ca  http://www.unioncdmx.mx/articulo/2020/06/03/ed...
#
#                                  newspaper_uid                         host
# uid
# a208fa9260371d726a41b10b41ff83bc      eltiempo       www.eluniversal.com.mx
# 602fe4651de5d33fa8b8a896179d2805      eltiempo           www.unionpuebla.mx
# 785bd930682054e238b68a7bd8dfffbe      eltiempo               www.viveusa.mx
# 8575c3932ba6cb712425f5b20c6ee6bc      eltiempo               www.viveusa.mx
# e719ff2dcc196a496b8dd11b3c2062e4      eltiempo  www.eluniversalqueretaro.mx
# ...                                        ...                          ...
# aa97a9136824bfced0e892686b81b6ee      eltiempo       www.eluniversal.com.mx
# 1e6f4ed28824897fe2c39e7e15643dfc      eltiempo    oaxaca.eluniversal.com.mx
# 67e5438eba106c3959093ff2f5b0f5dd      eltiempo       www.eluniversal.com.mx
# 17b73d5477c6ed9c35ff467370cc4325      eltiempo                  de10.com.mx
# 5d46615728015b7fd8282292d4d6c7ca      eltiempo             www.unioncdmx.mx
#
# [130 rows x 5 columns]

# %% [markdown]
# # Data Enrichment

# %%
# 6 Tokenizar el título y el body
import nltk
from nltk.corpus import stopwords 

stop_words = set(stopwords.words('spanish'))


def tokenize_column(df, column_name):
    return (
        df
        .dropna()
        .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
        .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
        .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
        .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
        .apply(lambda valid_word_list: len(valid_word_list))
    )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')

# %% [markdown]
# # Duplicate values

# %%
# 8. Eliminar duplicados

el_universal['title'].value_counts()
# Out:
# eiza gonzalez se disculpa por blackface que mostro en telenovela                 1
# Belinda, edad, estatura y otros datos de la coach de La Voz                      1
# Italia podrÃ­a recibir tres carreras de F1 este aÃ±o                             1
# salma hayek baila en bikini con su throwback mas atrevido                        1
# demi rose la modelo que causa sensacion en las redes sociales                    1
#                                                                                 ..
# Cruz Azul confirma: tres futbolistas con Covid-19; cuatro sospechosos            1
# Casos de Covid-19 en YucatÃ¡n, Quintana Roo y Tabasco al 27 de junio             1
# elecciones 2020 quien puede votar en estados unidos y quien no                   1
# Citan a periodo extraordinario en el Senado por paquete legislativo del T-MEC    1
# Gattuso elogia al 'Chucky': La velocidad de Hirving Lozano es una locura         1
# Name: title, Length: 130, dtype: int64

# %%
el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %% [markdown]
# # Final TAble

# %%
el_universal
# Out:
#                                                                                body  \
# uid
# a208fa9260371d726a41b10b41ff83bc  Los Rolling Stones amenazaron el domingo al pr...
# 602fe4651de5d33fa8b8a896179d2805  Como parte de las medidas de apoyo a las famil...
# 785bd930682054e238b68a7bd8dfffbe  \r\nLa actriz Emilia Clarke fue captada por lo...
# 8575c3932ba6cb712425f5b20c6ee6bc  \r\nLos Centros para el Control y la PrevenciÃ...
# e719ff2dcc196a496b8dd11b3c2062e4  \r\nDurante la llamada â€œnueva normalidadâ€� ...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  Durante esta Ã©poca de pandemia el influencer ...
# 1e6f4ed28824897fe2c39e7e15643dfc  \r\nLa FiscalÃ­a General del Estado de Oaxaca ...
# 67e5438eba106c3959093ff2f5b0f5dd  \r\nGuanajuato. â€” Este sÃ¡bado se realizÃ³ l...
# 17b73d5477c6ed9c35ff467370cc4325  Demi Rose Mawby es una modelo britÃ¡nica que c...
# 5d46615728015b7fd8282292d4d6c7ca  La ComisiÃ³n Metropolitana de Instituciones PÃ...
#
#                                                                               title  \
# uid
# a208fa9260371d726a41b10b41ff83bc  Los Rolling Stones amenazan con demandar a Don...
# 602fe4651de5d33fa8b8a896179d2805  CÃ³mo consigo una de Beca Benito JuÃ¡rez de pr...
# 785bd930682054e238b68a7bd8dfffbe  emilia clarke conquista londres con leggings n...
# 8575c3932ba6cb712425f5b20c6ee6bc  los cdc agregan tres posibles sintomas de covi...
# e719ff2dcc196a496b8dd11b3c2062e4  ContinÃºan bajas las ventas en el Centro de Qu...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  Juanma Salazar siente que ha crecido la compet...
# 1e6f4ed28824897fe2c39e7e15643dfc  Vinculan a sujeto que presuntamente atacÃ³ sex...
# 67e5438eba106c3959093ff2f5b0f5dd  No se presenta perito a juicio de mamÃ¡ de "El...
# 17b73d5477c6ed9c35ff467370cc4325  demi rose la modelo que causa sensacion en las...
# 5d46615728015b7fd8282292d4d6c7ca  Nuevas fechas para examen COMIPEMS 2020, Â¿cuÃ...
#
#                                                                                 url  \
# uid
# a208fa9260371d726a41b10b41ff83bc  http://www.eluniversal.com.mx/espectaculos/mus...
# 602fe4651de5d33fa8b8a896179d2805  http://www.unionpuebla.mx/articulo/2020/05/26/...
# 785bd930682054e238b68a7bd8dfffbe  https://www.viveusa.mx/showbiz/emilia-clarke-c...
# 8575c3932ba6cb712425f5b20c6ee6bc  https://www.viveusa.mx/bienestar/los-cdc-agreg...
# e719ff2dcc196a496b8dd11b3c2062e4  https://www.eluniversalqueretaro.mx/portada/co...
# ...                                                                             ...
# aa97a9136824bfced0e892686b81b6ee  http://www.eluniversal.com.mx/espectaculos/jua...
# 1e6f4ed28824897fe2c39e7e15643dfc  https://oaxaca.eluniversal.com.mx/estatal/28-0...
# 67e5438eba106c3959093ff2f5b0f5dd  http://www.eluniversal.com.mx/estados/no-se-pr...
# 17b73d5477c6ed9c35ff467370cc4325  https://de10.com.mx/cultura-digital/demi-rose-...
# 5d46615728015b7fd8282292d4d6c7ca  http://www.unioncdmx.mx/articulo/2020/06/03/ed...
#
#                                  newspaper_uid                         host  \
# uid
# a208fa9260371d726a41b10b41ff83bc      eltiempo       www.eluniversal.com.mx
# 602fe4651de5d33fa8b8a896179d2805      eltiempo           www.unionpuebla.mx
# 785bd930682054e238b68a7bd8dfffbe      eltiempo               www.viveusa.mx
# 8575c3932ba6cb712425f5b20c6ee6bc      eltiempo               www.viveusa.mx
# e719ff2dcc196a496b8dd11b3c2062e4      eltiempo  www.eluniversalqueretaro.mx
# ...                                        ...                          ...
# aa97a9136824bfced0e892686b81b6ee      eltiempo       www.eluniversal.com.mx
# 1e6f4ed28824897fe2c39e7e15643dfc      eltiempo    oaxaca.eluniversal.com.mx
# 67e5438eba106c3959093ff2f5b0f5dd      eltiempo       www.eluniversal.com.mx
# 17b73d5477c6ed9c35ff467370cc4325      eltiempo                  de10.com.mx
# 5d46615728015b7fd8282292d4d6c7ca      eltiempo             www.unioncdmx.mx
#
#                                   n_tokens_title  n_tokens_body
# uid
# a208fa9260371d726a41b10b41ff83bc               6             21
# 602fe4651de5d33fa8b8a896179d2805               5             21
# 785bd930682054e238b68a7bd8dfffbe               6              9
# 8575c3932ba6cb712425f5b20c6ee6bc               7             11
# e719ff2dcc196a496b8dd11b3c2062e4               4             13
# ...                                          ...            ...
# aa97a9136824bfced0e892686b81b6ee               4             11
# 1e6f4ed28824897fe2c39e7e15643dfc               7             14
# 67e5438eba106c3959093ff2f5b0f5dd               4             15
# 17b73d5477c6ed9c35ff467370cc4325               7             21
# 5d46615728015b7fd8282292d4d6c7ca               4             15
#
# [130 rows x 7 columns]
