# %%
import pandas as pd
import numpy as np

# %%
el_tiempo = pd.read_csv('eltiempo_2020_06_28_articles.csv')

# %%
el_tiempo
# Out:
#                                                  body  \
# 0   Les atribuyen, y la inglesa ‘The Economist’ lo...
# 1   \r\n\r\n\r\n\r\n\r\n\r\nBarranquilla\r\n\r\n03...
# 2   Luego de la entrevista de James Rodríguez esta...
# 3   Hay efemérides que al mirarlas y comparar el p...
# 4   La Policía Metropolitana de Cartagena rechazo ...
# ..                                                ...
# 69  Atalanta sigue ganando a ritmo colombiano. Est...
# 70  El cuerpo sin vida de una mujer que falleció p...
# 71  La Policía Metropolitana de Cali, en una rápid...
# 72  \r\n\r\n\r\n\r\n\r\n\r\nBarranquilla\r\n\r\n03...
# 73  La Fiscalía General de la Nación abrió una inv...
#
#                                                 title  \
# 0                                                 NaN
# 1   \r\nJames, suplente nuevamente, y los memes no...
# 2   James deja entrever que se va del Real Madrid ...
# 3   Estudio resalta las series y películas LGBTQ+ ...
# ...

# %%
# dictionary like 

el_tiempo['title']
# Out:
# 0                                                   NaN
# 1     \r\nJames, suplente nuevamente, y los memes no...
# 2     James deja entrever que se va del Real Madrid ...
# 3     Estudio resalta las series y películas LGBTQ+ ...
# 4     Policías que provocaron accidente en Cartagena...
#                             ...
# 69    Doblete de Muriel: ¡tremendos goles del colomb...
# 70    Familia sacó un cadáver de una clínica en Sole...
# 71    Cae presunta banda de secuestradores de la que...
# 72    \r\nJames, suplente nuevamente, y los memes no...
# 73    Fiscalía investiga muerte de joven durante des...
# Name: title, Length: 74, dtype: object

# %%
el_tiempo[['title','body']]
# Out:
#                                                 title  \
# 0                                                 NaN
# 1   \r\nJames, suplente nuevamente, y los memes no...
# 2   James deja entrever que se va del Real Madrid ...
# 3   Estudio resalta las series y películas LGBTQ+ ...
# 4   Policías que provocaron accidente en Cartagena...
# ..                                                ...
# 69  Doblete de Muriel: ¡tremendos goles del colomb...
# 70  Familia sacó un cadáver de una clínica en Sole...
# 71  Cae presunta banda de secuestradores de la que...
# 72  \r\nJames, suplente nuevamente, y los memes no...
# 73  Fiscalía investiga muerte de joven durante des...
#
#                                                  body
# 0   Les atribuyen, y la inglesa ‘The Economist’ lo...
# 1   \r\n\r\n\r\n\r\n\r\n\r\nBarranquilla\r\n\r\n03...
# 2   Luego de la entrevista de James Rodríguez esta...
# 3   Hay efemérides que al mirarlas y comparar el p...
# ...

# %%
#numpy like

el_tiempo.iloc[10:15]
# Out:
#                                                  body  \
# 10  \r\n\r\n\r\n\r\n\r\n\r\nBarranquilla\r\n\r\n03...
# 11  \r\n\r\n\r\n\r\n\r\n\r\nBarranquilla\r\n\r\n04...
# 12  La alcaldesa de Bogotá Claudia López anunció a...
# 13  \r\n\r\n\r\n\r\n\r\n\r\nAtlántico\r\n\r\n05:30...
# 14  Infame, no de otra forma puede calificarse un ...
#
#                                                 title  \
# 10  \r\nJames, suplente nuevamente, y los memes no...
# 11  \r\nJames, suplente nuevamente, y los memes no...
# 12  Claudia López le pide al Presidente que vuelva...
# 13                      Héroes en tiempos de pandemia
# 14          El peor de los crímenes / Sexo con Esther
#
#                                                   url
# 10  https://eltiempo.com/cultura/gente/pasion-de-g...
# 11  https://eltiempo.com/cultura/gente/en-fotos-ac...
# 12  https://eltiempo.com/bogota/coronavirus-en-bog...
# 13  https://eltiempo.com/cultura/gente/historias-d...
# ...

# %%
el_tiempo.iloc[66]['title']
# Out:
# 'Así nos reinventamos'

# %%
el_tiempo.loc[:,]
